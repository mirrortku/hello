# %%
1 = 4 #int
# Out:
#   File "<ipython-input-3-3877b1fc2a4b>", line 1
#     1 = 4 #int
# SyntaxError: can't assign to literal

# %%
i = 4 #int

# %%
type(f)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-9b1b2ea71b9c> in <module>()
# ----> 1 type(f)
#
# NameError: name 'f' is not defined

# %%
type(i)
# Out:
# int

# %%
f = 3.14

# %%
type(f)
# Out:
# float

# %%
b = true
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-57717e1d1ac5> in <module>()
# ----> 1 b = true
#
# NameError: name 'true' is not defined

# %%
b = True

# %%
type(b)
# Out:
# bool

# %%
hungry = True

# %%
sleep = False

# %%
not hungry
# Out:
# False

# %%
hungry and sleep
# Out:
# False

# %%
hungry or sleep
# Out:
# True

# %%
ss = "This is a string"

# %%
ss
# Out:
# 'This is a string'

# %%
from skimage import io

img1=io.imread('arduino.jpg', as_grey=True)

print(type(img1))
print(img1.shape)

io.imshow(img1)
io.show()
# Out:
# <class 'numpy.ndarray'>
# (152, 189)
# D:\Anaconda\lib\site-packages\skimage\io\_plugins\matplotlib_plugin.py:51: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   out_of_range_float = (np.issubdtype(image.dtype, np.float) and
